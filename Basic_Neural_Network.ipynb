# %%
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
# Out:
# 2023-03-20 13:00:01.588433: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=1)

# Create df with data
df = pd.DataFrame(X, columns=['Feature 1', 'Feature 2'])
df['Target'] = y

# Plot data
df.plot.scatter(x='Feature 1', y='Feature 2', c='Target', colormap='winter')
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Scaler
X_scaler = skl.preprocessing.StandardScaler()

# Fit scaler
X_scaler.fit(X_train)

# Scale data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create Keras Sequential model
nn_model = tf.keras.models.Sequential()
# Out:
# 2023-03-20 13:08:01.474815: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Add our first Dense layer
nn_model.add(tf.keras.layers.Dense(units=1, activation='relu', input_dim=2))

# %%
# Add output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile Sepuential model and customize metrics
nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 2s 4ms/step - loss: 0.4349 - accuracy: 0.9787
# Epoch 2/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.4229 - accuracy: 1.0000
# Epoch 3/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4111 - accuracy: 1.0000
# Epoch 4/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3998 - accuracy: 1.0000
# Epoch 5/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3889 - accuracy: 1.0000
# Epoch 6/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3784 - accuracy: 1.0000
# Epoch 7/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3684 - accuracy: 1.0000
# Epoch 8/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3587 - accuracy: 1.0000
# Epoch 9/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3494 - accuracy: 1.0000
# Epoch 10/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3405 - accuracy: 1.0000
# Epoch 11/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3319 - accuracy: 1.0000
# Epoch 12/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3237 - accuracy: 1.0000
# Epoch 13/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3158 - accuracy: 1.0000
# Epoch 14/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3082 - accuracy: 1.0000
# Epoch 15/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3009 - accuracy: 1.0000
# Epoch 16/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2939 - accuracy: 1.0000
# Epoch 17/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2872 - accuracy: 1.0000
# Epoch 18/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2807 - accuracy: 1.0000
# Epoch 19/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2744 - accuracy: 1.0000
# Epoch 20/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2684 - accuracy: 1.0000
# Epoch 21/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2626 - accuracy: 1.0000
# Epoch 22/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2569 - accuracy: 1.0000
# Epoch 23/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.2515 - accuracy: 1.0000
# Epoch 24/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2462 - accuracy: 1.0000
# Epoch 25/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2411 - accuracy: 1.0000
# Epoch 26/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2361 - accuracy: 1.0000
# Epoch 27/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2313 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2267 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2222 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2178 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2136 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2095 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2055 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2016 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1978 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1941 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1905 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1870 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1836 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1803 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1771 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1739 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1709 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1679 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1649 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1621 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1592 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1539 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1513 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1487 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1462 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1437 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1414 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1390 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1367 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1345 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1323 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1281 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1261 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1241 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1221 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1202 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1183 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1164 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1146 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1129 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1111 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1094 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1078 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1061 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1045 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1029 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1014 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0999 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0984 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0969 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0955 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0927 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0914 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0901 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0888 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0875 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0862 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0850 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0838 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0826 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0815 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0803 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0792 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0781 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0749 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0739 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0729 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0719 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0709 - accuracy: 1.0000

# %%
# Create DF containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1, len(fit_model.history['loss'])+1))

# plot the loss
history_df.plot(y='loss')
# Out:
# <AxesSubplot:>

# %%
# Plot accuracy
history_df.plot(y='accuracy')
# Out:
# <AxesSubplot:>

# %%
# Evaluate model using test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 8/8 - 0s - loss: 0.0745 - accuracy: 1.0000 - 498ms/epoch - 62ms/step
# Loss: 0.07448171079158783, Accuracy: 1.0

# %%
# Predict classificatio of a new set of blob data
new_X, new_y = make_blobs(n_samples=10, centers=2, n_features=2, random_state=1)
new_X_scaled = X_scaler.transform(new_X)
(nn_model.predict(new_X_scaled) > 0.5).astype('int32')
# Out:
# 1/1 [==============================] - 0s 149ms/step
# array([[1],
#        [1],
#        [1],
#        [1],
#        [0],
#        [0],
#        [0],
#        [1],
#        [0],
#        [0]], dtype=int32)

# %%
from sklearn.datasets import make_moons

# Create dummy moon data
x_moons
